# %% [markdown]
# # Download experimental data:
# - NLB data
# - BCI example datasets (Golub 2018, Hennig 2018, Degenhard 2020)
# - Cycling task data, Russo et al. 2018

# %% [markdown]
# # NLB data.

# %%
# Install these packages:

# For downloading the datasets
# !pip install dandi

# For the NLB wrappers. These will be used in `data_loaders.py`
# !pip install -U scikit-learn
# !pip install git+https://github.com/neurallatents/nlb_tools.git
# Out:
# Collecting dandi
#   Downloading dandi-0.55.1-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.4/297.4 KB 5.1 MB/s eta 0:00:004.2 MB/s eta 0:00:01
# Collecting pycryptodomex
#   Downloading pycryptodomex-3.18.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 35.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting click
#   Downloading click-8.1.4-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 KB 23.5 MB/s eta 0:00:00
# Collecting ruamel.yaml<1,>=0.15
#   Downloading ruamel.yaml-0.17.32-py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 9.9 MB/s eta 0:00:00
# Collecting interleave~=0.1
#   Using cached interleave-0.2.1-py3-none-any.whl (11 kB)
# Collecting fasteners
#   Using cached fasteners-0.18-py3-none-any.whl (18 kB)
# Requirement already satisfied: python-dateutil in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from dandi) (2.8.2)
# Collecting humanize
#   Downloading humanize-4.7.0-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 KB 11.6 MB/s eta 0:00:00
# Collecting click-didyoumean
#   Using cached click_didyoumean-0.3.0-py3-none-any.whl (2.7 kB)
# Collecting keyrings.alt
#   Using cached keyrings.alt-4.2.0-py3-none-any.whl (20 kB)
# Collecting pyout!=0.6.0,>=0.5
#   Downloading pyout-0.7.3-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.7/51.7 KB 22.5 MB/s eta 0:00:00
# Collecting semantic-version
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting etelemetry>=0.2.2
#   Using cached etelemetry-0.3.0-py3-none-any.whl (6.3 kB)
# Requirement already satisfied: joblib in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from dandi) (1.3.1)
# Requirement already satisfied: requests~=2.20 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from dandi) (2.31.0)
# Collecting zarr~=2.10
#   Downloading zarr-2.15.0-py3-none-any.whl (206 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.1/206.1 KB 14.0 MB/s eta 0:00:00
# Collecting zarr-checksum
#   Downloading zarr_checksum-0.2.9-py3-none-any.whl (13 kB)
# Collecting bidsschematools~=0.7.0
#   Downloading bidsschematools-0.7.1-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 29.7 MB/s eta 0:00:00m eta 0:00:01
# Requirement already satisfied: packaging in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from dandi) (23.1)
# Collecting tenacity
#   Downloading tenacity-8.2.2-py3-none-any.whl (24 kB)
# Collecting hdmf!=3.5.0
#   Downloading hdmf-3.7.0-py3-none-any.whl (327 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.7/327.7 KB 25.6 MB/s eta 0:00:00
# Collecting pydantic>=1.9.0
#   Downloading pydantic-2.0.2-py3-none-any.whl (359 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.1/359.1 KB 44.9 MB/s eta 0:00:00
# Collecting pynwb!=1.1.0,!=2.3.0,>=1.0.3
#   Downloading pynwb-2.3.3-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.9/131.9 KB 11.0 MB/s eta 0:00:00
# Collecting keyring!=23.9.0
#   Downloading keyring-24.2.0-py3-none-any.whl (37 kB)
# Collecting dandischema~=0.8.0
#   Downloading dandischema-0.8.4-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.2/63.2 KB 23.8 MB/s eta 0:00:00
# Collecting fscacher>=0.3.0
#   Downloading fscacher-0.3.0-py3-none-any.whl (11 kB)
# Collecting nwbinspector>=0.4.28
#   Downloading nwbinspector-0.4.29-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 KB 6.3 MB/s eta 0:00:00
# Collecting appdirs
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pyyaml in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from bidsschematools~=0.7.0->dandi) (6.0)
# Requirement already satisfied: jsonschema[format] in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from dandischema~=0.8.0->dandi) (4.18.2)
# Collecting pydantic[email]<2.0,>=1.8.1
#   Downloading pydantic-1.10.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 25.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting ci-info>=0.2
#   Using cached ci_info-0.3.0-py3-none-any.whl (7.8 kB)
# Requirement already satisfied: pandas>=1.0.5 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from hdmf!=3.5.0->dandi) (2.0.3)
# Requirement already satisfied: scipy>=1.4 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from hdmf!=3.5.0->dandi) (1.11.1)
# Collecting h5py>=2.10
#   Downloading h5py-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 22.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: numpy>=1.18 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from hdmf!=3.5.0->dandi) (1.25.1)
# Collecting jaraco.classes
#   Downloading jaraco.classes-3.3.0-py3-none-any.whl (5.9 kB)
# Collecting SecretStorage>=3.2
#   Using cached SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting importlib-metadata>=4.11.4
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Collecting jeepney>=0.4.2
#   Using cached jeepney-0.8.0-py3-none-any.whl (48 kB)
# Requirement already satisfied: tqdm in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from nwbinspector>=0.4.28->dandi) (4.65.0)
# Collecting isodate
#   Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Collecting natsort
#   Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.5.0-py3-none-any.whl (11 kB)
# Collecting pydantic-core==2.1.2
#   Downloading pydantic_core-2.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 74.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from pydantic>=1.9.0->dandi) (4.7.1)
# Requirement already satisfied: setuptools in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from pynwb!=1.1.0,!=2.3.0,>=1.0.3->dandi) (59.6.0)
# Collecting blessed
#   Downloading blessed-1.20.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 KB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from python-dateutil->dandi) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from requests~=2.20->dandi) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from requests~=2.20->dandi) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from requests~=2.20->dandi) (2023.5.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from requests~=2.20->dandi) (2.0.3)
# Collecting ruamel.yaml.clib>=0.2.7
#   Downloading ruamel.yaml.clib-0.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 KB 93.8 MB/s eta 0:00:00
# Collecting numcodecs>=0.10.0
#   Downloading numcodecs-0.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 37.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting asciitree
#   Using cached asciitree-0.3.3.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting boto3<2.0,>=1.24
#   Downloading boto3-1.28.2-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 KB 8.9 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 KB 8.8 MB/s eta 0:00:00
# Collecting botocore<1.32.0,>=1.31.2
#   Downloading botocore-1.31.2-py3-none-any.whl (11.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 33.2 MB/s eta 0:00:00m eta 0:00:01:01:01
# Collecting zipp>=0.5
#   Downloading zipp-3.16.1-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: attrs>=22.2.0 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from jsonschema[format]->dandischema~=0.8.0->dandi) (23.1.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from jsonschema[format]->dandischema~=0.8.0->dandi) (0.8.10)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from jsonschema[format]->dandischema~=0.8.0->dandi) (2023.6.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from jsonschema[format]->dandischema~=0.8.0->dandi) (0.29.1)
# Collecting entrypoints
#   Using cached entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from pandas>=1.0.5->hdmf!=3.5.0->dandi) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from pandas>=1.0.5->hdmf!=3.5.0->dandi) (2023.3)
# Collecting email-validator>=1.0.3
#   Downloading email_validator-2.0.0.post2-py3-none-any.whl (31 kB)
# Collecting cryptography>=2.0
#   Downloading cryptography-41.0.2-cp37-abi3-manylinux_2_28_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 30.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: wcwidth>=0.1.4 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from blessed->pyout!=0.6.0,>=0.5->dandi) (0.2.6)
# Collecting more-itertools
#   Downloading more_itertools-9.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 KB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: jsonpointer>1.13 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from jsonschema[format]->dandischema~=0.8.0->dandi) (2.4)
# Collecting rfc3987
#   Using cached rfc3987-1.3.8-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: uri-template in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from jsonschema[format]->dandischema~=0.8.0->dandi) (1.3.0)
# Requirement already satisfied: isoduration in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from jsonschema[format]->dandischema~=0.8.0->dandi) (20.11.0)
# Requirement already satisfied: webcolors>=1.11 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from jsonschema[format]->dandischema~=0.8.0->dandi) (1.13)
# Requirement already satisfied: rfc3339-validator in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from jsonschema[format]->dandischema~=0.8.0->dandi) (0.1.4)
# Requirement already satisfied: fqdn in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from jsonschema[format]->dandischema~=0.8.0->dandi) (1.5.1)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 KB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.12 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring!=23.9.0->dandi) (1.15.1)
# Collecting dnspython>=2.0.0
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 KB 63.0 MB/s eta 0:00:00
# Requirement already satisfied: arrow>=0.15.0 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from isoduration->jsonschema[format]->dandischema~=0.8.0->dandi) (1.2.3)
# Requirement already satisfied: pycparser in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring!=23.9.0->dandi) (2.21)
# Using legacy 'setup.py install' for asciitree, since package 'wheel' is not installed.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 165, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 205, in wrapper
#     return func(self, options, args)
#   File "/home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages/pip/_internal/commands/install.py", line 389, in run
#     to_install = resolver.get_installation_order(requirement_set)
#   File "/home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/resolver.py", line 188, in get_installation_order
#     weights = get_topological_weights(
#   File "/home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/resolver.py", line 276, in get_topological_weights
#     assert len(weights) == expected_node_count
# AssertionError
# Requirement already satisfied: scikit-learn in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: numpy>=1.17.3 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from scikit-learn) (1.25.1)
# Requirement already satisfied: scipy>=1.5.0 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from scikit-learn) (3.2.0)
# Collecting git+https://github.com/neurallatents/nlb_tools.git
#   Cloning https://github.com/neurallatents/nlb_tools.git to /tmp/pip-req-build-syk2zrfm
#   Running command git clone --filter=blob:none --quiet https://github.com/neurallatents/nlb_tools.git /tmp/pip-req-build-syk2zrfm
#   Resolved https://github.com/neurallatents/nlb_tools.git to commit 75c5bf0401b84cf53fba9dc57449e3252d4acb88
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from nlb-tools==0.0.2) (1.25.1)
# Collecting pandas<=1.3.4,>=1.0.0
#   Using cached pandas-1.3.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
# Collecting h5py<4,>=2.9
#   Using cached h5py-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
# Collecting pynwb
#   Using cached pynwb-2.3.3-py3-none-any.whl (131 kB)
# Requirement already satisfied: scikit-learn in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from nlb-tools==0.0.2) (1.3.0)
# Requirement already satisfied: scipy in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from nlb-tools==0.0.2) (1.11.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from pandas<=1.3.4,>=1.0.0->nlb-tools==0.0.2) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from pandas<=1.3.4,>=1.0.0->nlb-tools==0.0.2) (2023.3)
# Collecting hdmf>=3.5.4
#   Using cached hdmf-3.7.0-py3-none-any.whl (327 kB)
# Requirement already satisfied: setuptools in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from pynwb->nlb-tools==0.0.2) (59.6.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from scikit-learn->nlb-tools==0.0.2) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from scikit-learn->nlb-tools==0.0.2) (3.2.0)
# Collecting ruamel-yaml>=0.16
#   Using cached ruamel.yaml-0.17.32-py3-none-any.whl (112 kB)
# Requirement already satisfied: jsonschema>=2.6.0 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from hdmf>=3.5.4->pynwb->nlb-tools==0.0.2) (4.18.2)
# Requirement already satisfied: six>=1.5 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from python-dateutil>=2.7.3->pandas<=1.3.4,>=1.0.0->nlb-tools==0.0.2) (1.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from jsonschema>=2.6.0->hdmf>=3.5.4->pynwb->nlb-tools==0.0.2) (2023.6.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from jsonschema>=2.6.0->hdmf>=3.5.4->pynwb->nlb-tools==0.0.2) (0.8.10)
# Requirement already satisfied: referencing>=0.28.4 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from jsonschema>=2.6.0->hdmf>=3.5.4->pynwb->nlb-tools==0.0.2) (0.29.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/friedrich/.virtualenvs/venv_oblique/lib/python3.10/site-packages (from jsonschema>=2.6.0->hdmf>=3.5.4->pynwb->nlb-tools==0.0.2) (23.1.0)
# Collecting ruamel.yaml.clib>=0.2.7
#   Using cached ruamel.yaml.clib-0.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (485 kB)
# Building wheels for collected packages: nlb-tools
#   Building wheel for nlb-tools (pyproject.toml) ... done
#   Created wheel for nlb-tools: filename=nlb_tools-0.0.2-py3-none-any.whl size=34377 sha256=93c79baa5cccb62b4bb97df9ae0c48e98abf370667d079ceb81f3b82f9b3976e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2b02gnc_/wheels/db/f1/81/e0fabfc232e056102d5fca550b8e96a117cb3a0f0dde1a1085
# Successfully built nlb-tools
# Installing collected packages: ruamel.yaml.clib, h5py, ruamel-yaml, pandas, hdmf, pynwb, nlb-tools
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# Successfully installed h5py-3.9.0 hdmf-3.7.0 nlb-tools-0.0.2 pandas-1.3.4 pynwb-2.3.3 ruamel-yaml-0.17.32 ruamel.yaml.clib-0.2.7

# %%
import os
from specs import data_path
data_path_nlb = os.path.join(data_path, "neural_latents")
if not os.path.exists(data_path_nlb): os.mkdir(data_path_nlb)

# Dataset to be downloaded
dataset_names = [
    'mc_maze_large',
    # 'mc_maze_small',
    'mc_rtt', 
]

for dataset_name in dataset_names:
    if dataset_name == "mc_maze":
        dataset_id = '000128'
    if dataset_name == "mc_maze_large":
        dataset_id = '000138'
    if dataset_name == "mc_maze_medium":
        dataset_id = '000139'
    if dataset_name == "mc_maze_small":
        dataset_id = '000140'
    if dataset_name == "mc_rtt":
        dataset_id = '000129'
    if dataset_name == "area2_bump":
        dataset_id = '000127'
    if dataset_name == "dmfc_rsg":
        dataset_id = '000130'
    
    # If necessary, download dataset from DANDI
    dataset_path = os.path.join(data_path_nlb, dataset_id)
    if not os.path.exists(dataset_path):
        os.system("dandi download https://dandiarchive.org/dandiset/" + dataset_id + " -o " + data_path_nlb)
# Out:
# 2023-07-13 16:28:26,228 [ WARNING] A newer version (0.55.1) of dandi/dandi-cli is available. You are using 0.46.6
# 2023-07-13 16:28:26,395 [    INFO] Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2023-07-13 16:28:26,395 [    INFO] NumExpr defaulting to 8 threads.
# PATH                                                              SIZE     DONE           DONE% CHECKSUM STATUS          MESSAGE
# dandiset.yaml                                                                                            done            updated
# sub-Jenkins/sub-Jenkins_ses-small_desc-test_ecephys.nwb           689.3 kB 689.3 kB        100%    ok    done
# sub-Jenkins/sub-Jenkins_ses-small_desc-train_behavior+ecephys.nwb 29.2 MB  29.2 MB         100%    ok    done
# Summary:                                                          29.9 MB  29.9 MB                       3 done          1 updated
#                                                                            100.00%
# 2023-07-13 16:28:31,618 [    INFO] Logs saved in /home/friedrich/.cache/dandi-cli/log/20230713142825Z-31178.log

# %% [markdown]
# # BCI datasets

# %%
import os
import requests

data_path_bci = os.path.join(data_path, "bci")
if not os.path.exists(data_path_bci): os.mkdir(data_path_bci)

# Golub 2018
url = "https://github.com/mattgolub/bci_learning/raw/master/exampleData.mat"
file_name = "20120305.mat"
data_file = os.path.join(data_path_bci, file_name)
if not os.path.exists(data_file):
    myfile = requests.get(url, allow_redirects=True)
    open(data_file, 'wb').write(myfile.content)

# Hennig 2018
url = "https://github.com/mobeets/neural-redundancy-elife2018/raw/master/data/sessions/20131218.mat"
file_name = url.split('/')[-1]
data_file = os.path.join(data_path_bci, file_name)
if not os.path.exists(data_file):
    myfile = requests.get(url, allow_redirects=True)
    open(data_file, 'wb').write(myfile.content)
    
# Degenhard 2020
url = "https://github.com/alandegenhart/stabilizedbci/raw/master/data/20160325.mat"
file_name = url.split('/')[-1]
data_file = os.path.join(data_path_bci, file_name)
if not os.path.exists(data_file):
    myfile = requests.get(url, allow_redirects=True)
    open(data_file, 'wb').write(myfile.content)

# %% [markdown]
# # Russo et al., 2018

# %%
import os
import requests

data_path_russo = os.path.join(data_path, "russo_monkey_data")
if not os.path.exists(data_path_russo): os.mkdir(data_path_russo)

url = "https://data.mendeley.com/public-files/datasets/tfcwp8bp5j/files/2f73219e-604c-4e8a-a5bb-92850aac496a/file_downloaded"
file_name = "Cousteau_tt.mat"
data_file = os.path.join(data_path_russo, file_name)
if not os.path.exists(data_file):
    myfile = requests.get(url, allow_redirects=True)
    open(data_file, 'wb').write(myfile.content)

url = "https://data.mendeley.com/public-files/datasets/tfcwp8bp5j/files/fe378e59-e33c-4b34-9980-8ee9e29f8819/file_downloaded"
file_name = "Drake_tt.mat"
data_file = os.path.join(data_path_russo, file_name)
if not os.path.exists(data_file):
    myfile = requests.get(url, allow_redirects=True)
    open(data_file, 'wb').write(myfile.content)
